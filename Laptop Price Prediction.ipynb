# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\Dell Latitude 3460\Downloads\laptopData.csv')

# %%
data.head(10)
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 5         5.0    Acer   Notebook   15.6                            1366x768
# 6         6.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 7         7.0   Apple  Ultrabook   13.3                            1440x900
# 8         8.0    Asus  Ultrabook     14                   Full HD 1920x1080
# 9         9.0    Acer  Ultrabook     14         IPS Panel Full HD 1920x1080
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# ...

# %%
data.shape
# Out:
# (1303, 12)

# %%
data.describe(include='all')
# Out:
#          Unnamed: 0 Company  TypeName Inches   ScreenResolution  \
# count   1273.000000    1273      1273   1273               1273
# unique          NaN      19         6     25                 40
# top             NaN  Lenovo  Notebook   15.6  Full HD 1920x1080
# freq            NaN     290       710    640                495
# mean     652.674784     NaN       NaN    NaN                NaN
# std      376.493027     NaN       NaN    NaN                NaN
# min        0.000000     NaN       NaN    NaN                NaN
# 25%      327.000000     NaN       NaN    NaN                NaN
# 50%      652.000000     NaN       NaN    NaN                NaN
# 75%      980.000000     NaN       NaN    NaN                NaN
# max     1302.000000     NaN       NaN    NaN                NaN
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1273  1273       1273                   1273
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
data1 = data.drop(['Unnamed: 0'], axis=1)

# %%
data2 = data1.dropna()

# %%
data2.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
data2.head(10)
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 5    Acer   Notebook   15.6                            1366x768
# 6   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 7   Apple  Ultrabook   13.3                            1440x900
# 8    Asus  Ultrabook     14                   Full HD 1920x1080
# 9    Acer  Ultrabook     14         IPS Panel Full HD 1920x1080
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# ...

# %%
import re

def extract_resolution(text):
    match = re.search(r'\d{3,4}x\d{3,4}', text)
    if match:
        return match.group()
    return None

# %%
data2['Resolution'] = data2['ScreenResolution'].apply(extract_resolution)
# Out:
# C:\Users\Dell Latitude 3460\AppData\Local\Temp\ipykernel_16292\1504980307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['Resolution'] = data2['ScreenResolution'].apply(extract_resolution)

# %%
data2.head(10)
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 5    Acer   Notebook   15.6                            1366x768
# 6   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 7   Apple  Ultrabook   13.3                            1440x900
# 8    Asus  Ultrabook     14                   Full HD 1920x1080
# 9    Acer  Ultrabook     14         IPS Panel Full HD 1920x1080
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# ...

# %%
data3 = data2.drop(['ScreenResolution'], axis= 1)

# %%
data3.head(10)
# Out:
#   Company   TypeName Inches                         Cpu   Ram  \
# 0   Apple  Ultrabook   13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Ultrabook   13.3        Intel Core i5 1.8GHz   8GB
# 2      HP   Notebook   15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  Ultrabook   15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  Ultrabook   13.3        Intel Core i5 3.1GHz   8GB
# 5    Acer   Notebook   15.6     AMD A9-Series 9420 3GHz   4GB
# 6   Apple  Ultrabook   15.4        Intel Core i7 2.2GHz  16GB
# 7   Apple  Ultrabook   13.3        Intel Core i5 1.8GHz   8GB
# 8    Asus  Ultrabook     14  Intel Core i7 8550U 1.8GHz  16GB
# 9    Acer  Ultrabook     14  Intel Core i5 8250U 1.6GHz   8GB
#
#                 Memory                           Gpu       OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640       macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000       macOS  1.34kg
# ...

# %%
data3['Cpu'].unique()
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Core i5 7300HQ 2.5GHz',
#        'AMD E-Series E2-9000e 1.5GHz', 'Intel Core i5 1.6GHz',
#        'Intel Core i7 8650U 1.9GHz', 'Intel Atom x5-Z8300 1.44GHz',
#        'AMD E-Series E2-6110 1.5GHz', 'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
# ...

# %%
data3['Resolution'].value_counts()
# Out:
# Resolution
# 1920x1080    822
# 1366x768     301
# 3840x2160     42
# 3200x1800     26
# 1600x900      23
# 2560x1440     22
# 2560x1600      6
# 2304x1440      6
# 2256x1504      6
# 1440x900       4
# 2880x1800      4
# 2400x1600      4
# 1920x1200      4
# 2160x1440      2
# 2736x1824      1
# Name: count, dtype: int64

# %%
data3['CPU_Type'] = data3.Cpu.apply(
    lambda x: 'Samsung' if 'Samsung' in x else (
        'Intel' if 'Intel' in x else (
            'AMD' if 'AMD' in x else 'Other'
        )
    ))

data3['Memory_Type'] = data3.Memory.apply(
    lambda x: 'Flash Storage' if 'Flash' in x else (
        'HDD' if 'HDD' in x else 'SDD'
    )
)

data3['GPU'] = data3.Gpu.apply(
    lambda x: 'AMD' if 'AMD' in x else(
        'Nvidia' if 'Nvidia' in x else 'Intel'
    )
)

# %%
data3.head(10)
# Out:
#   Company   TypeName Inches                         Cpu   Ram  \
# 0   Apple  Ultrabook   13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Ultrabook   13.3        Intel Core i5 1.8GHz   8GB
# 2      HP   Notebook   15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  Ultrabook   15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  Ultrabook   13.3        Intel Core i5 3.1GHz   8GB
# 5    Acer   Notebook   15.6     AMD A9-Series 9420 3GHz   4GB
# 6   Apple  Ultrabook   15.4        Intel Core i7 2.2GHz  16GB
# 7   Apple  Ultrabook   13.3        Intel Core i5 1.8GHz   8GB
# 8    Asus  Ultrabook     14  Intel Core i7 8550U 1.8GHz  16GB
# 9    Acer  Ultrabook     14  Intel Core i5 8250U 1.6GHz   8GB
#
#                 Memory                           Gpu       OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640       macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000       macOS  1.34kg
# ...

# %%
data3.shape
# Out:
# (1273, 14)

# %%
data3['Weight'].value_counts()
# Out:
# Weight
# 2.2kg     111
# 2.1kg      57
# 2.4kg      43
# 2.3kg      41
# 2.5kg      37
#          ...
# 1.41kg      1
# 3.6kg       1
# 4.7kg       1
# 4.33kg      1
# 4.0kg       1
# Name: count, Length: 189, dtype: int64

# %%
data4 = data3.drop(['Cpu', 'Memory', 'Gpu'], axis=1)

# %%
data4.head(10)
# Out:
#   Company   TypeName Inches   Ram       OpSys  Weight        Price Resolution  \
# 0   Apple  Ultrabook   13.3   8GB       macOS  1.37kg   71378.6832  2560x1600
# 1   Apple  Ultrabook   13.3   8GB       macOS  1.34kg   47895.5232   1440x900
# 2      HP   Notebook   15.6   8GB       No OS  1.86kg   30636.0000  1920x1080
# 3   Apple  Ultrabook   15.4  16GB       macOS  1.83kg  135195.3360  2880x1800
# 4   Apple  Ultrabook   13.3   8GB       macOS  1.37kg   96095.8080  2560x1600
# 5    Acer   Notebook   15.6   4GB  Windows 10   2.1kg   21312.0000   1366x768
# 6   Apple  Ultrabook   15.4  16GB    Mac OS X  2.04kg  114017.6016  2880x1800
# 7   Apple  Ultrabook   13.3   8GB       macOS  1.34kg   61735.5360   1440x900
# 8    Asus  Ultrabook     14  16GB  Windows 10   1.3kg   79653.6000  1920x1080
# 9    Acer  Ultrabook     14   8GB  Windows 10   1.6kg   41025.6000  1920x1080
#
#   CPU_Type    Memory_Type     GPU
# 0    Intel            SDD   Intel
# 1    Intel  Flash Storage   Intel
# ...

# %%
data4['Ram'] = data4['Ram'].str.replace('GB', '', case=False).astype(int)

# %%
data4.head(10)
# Out:
#   Company   TypeName Inches  Ram       OpSys  Weight        Price Resolution  \
# 0   Apple  Ultrabook   13.3    8       macOS  1.37kg   71378.6832  2560x1600
# 1   Apple  Ultrabook   13.3    8       macOS  1.34kg   47895.5232   1440x900
# 2      HP   Notebook   15.6    8       No OS  1.86kg   30636.0000  1920x1080
# 3   Apple  Ultrabook   15.4   16       macOS  1.83kg  135195.3360  2880x1800
# 4   Apple  Ultrabook   13.3    8       macOS  1.37kg   96095.8080  2560x1600
# 5    Acer   Notebook   15.6    4  Windows 10   2.1kg   21312.0000   1366x768
# 6   Apple  Ultrabook   15.4   16    Mac OS X  2.04kg  114017.6016  2880x1800
# 7   Apple  Ultrabook   13.3    8       macOS  1.34kg   61735.5360   1440x900
# 8    Asus  Ultrabook     14   16  Windows 10   1.3kg   79653.6000  1920x1080
# 9    Acer  Ultrabook     14    8  Windows 10   1.6kg   41025.6000  1920x1080
#
#   CPU_Type    Memory_Type     GPU
# 0    Intel            SDD   Intel
# 1    Intel  Flash Storage   Intel
# ...

# %%
data4['Weight'].replace('?', np.nan, inplace=True)
# Out:
# C:\Users\Dell Latitude 3460\AppData\Local\Temp\ipykernel_16292\4215827875.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data4['Weight'].replace('?', np.nan, inplace=True)

# %%
data5 = data4.dropna(axis=0)

# %%
data5.isnull().sum()
# Out:
# Company        0
# TypeName       0
# Inches         0
# Ram            0
# OpSys          0
# Weight         0
# Price          0
# Resolution     0
# CPU_Type       0
# Memory_Type    0
# GPU            0
# dtype: int64

# %%
data5['Weight'] = data5['Weight'].str.replace('kg', '', case=False).astype(float)
# Out:
# C:\Users\Dell Latitude 3460\AppData\Local\Temp\ipykernel_16292\3211037864.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data5['Weight'] = data5['Weight'].str.replace('kg', '', case=False).astype(float)

# %%
data5.head(10)
# Out:
#   Company   TypeName Inches  Ram       OpSys  Weight        Price Resolution  \
# 0   Apple  Ultrabook   13.3    8       macOS    1.37   71378.6832  2560x1600
# 1   Apple  Ultrabook   13.3    8       macOS    1.34   47895.5232   1440x900
# 2      HP   Notebook   15.6    8       No OS    1.86   30636.0000  1920x1080
# 3   Apple  Ultrabook   15.4   16       macOS    1.83  135195.3360  2880x1800
# 4   Apple  Ultrabook   13.3    8       macOS    1.37   96095.8080  2560x1600
# 5    Acer   Notebook   15.6    4  Windows 10    2.10   21312.0000   1366x768
# 6   Apple  Ultrabook   15.4   16    Mac OS X    2.04  114017.6016  2880x1800
# 7   Apple  Ultrabook   13.3    8       macOS    1.34   61735.5360   1440x900
# 8    Asus  Ultrabook     14   16  Windows 10    1.30   79653.6000  1920x1080
# 9    Acer  Ultrabook     14    8  Windows 10    1.60   41025.6000  1920x1080
#
#   CPU_Type    Memory_Type     GPU
# 0    Intel            SDD   Intel
# 1    Intel  Flash Storage   Intel
# ...

# %%
res_split = data5['Resolution'].str.extract(r'(\d+)x(\d+)')
data5['Width'] = res_split[0].astype(int)
data5['Height'] = res_split[1].astype(int)
# Out:
# C:\Users\Dell Latitude 3460\AppData\Local\Temp\ipykernel_16292\783264666.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data5['Width'] = res_split[0].astype(int)
# C:\Users\Dell Latitude 3460\AppData\Local\Temp\ipykernel_16292\783264666.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data5['Height'] = res_split[1].astype(int)

# %%
data6 = data5.drop(['Resolution'], axis=1)

# %%
data6.head(10)
# Out:
#   Company   TypeName Inches  Ram       OpSys  Weight        Price CPU_Type  \
# 0   Apple  Ultrabook   13.3    8       macOS    1.37   71378.6832    Intel
# 1   Apple  Ultrabook   13.3    8       macOS    1.34   47895.5232    Intel
# 2      HP   Notebook   15.6    8       No OS    1.86   30636.0000    Intel
# 3   Apple  Ultrabook   15.4   16       macOS    1.83  135195.3360    Intel
# 4   Apple  Ultrabook   13.3    8       macOS    1.37   96095.8080    Intel
# 5    Acer   Notebook   15.6    4  Windows 10    2.10   21312.0000      AMD
# 6   Apple  Ultrabook   15.4   16    Mac OS X    2.04  114017.6016    Intel
# 7   Apple  Ultrabook   13.3    8       macOS    1.34   61735.5360    Intel
# 8    Asus  Ultrabook     14   16  Windows 10    1.30   79653.6000    Intel
# 9    Acer  Ultrabook     14    8  Windows 10    1.60   41025.6000    Intel
#
#      Memory_Type     GPU  Width  Height
# 0            SDD   Intel   2560    1600
# 1  Flash Storage   Intel   1440     900
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(data6.corr(), annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 sns.heatmap(data6.corr(), annot=True)
#       2 plt.show()
#
# File c:\Users\Dell Latitude 3460\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Dell Latitude 3460\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
data6['Weight'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1272 entries, 0 to 1302
# Series name: Weight
# Non-Null Count  Dtype
# --------------  -----
# 1272 non-null   float64
# dtypes: float64(1)
# memory usage: 19.9 KB

# %%
data6['Inches'].unique()
# Out:
# array(['13.3', '15.6', '15.4', '14', '12', '17.3', '13.5', '12.5', '13',
#        '18.4', '13.9', '11.6', '25.6', '35.6', '12.3', '27.3', '24',
#        '33.5', '?', '31.6', '17', '15', '14.1', '11.3', '10.1'],
#       dtype=object)

# %%
data6['Inches'].replace('?', np.nan, inplace=True)
# Out:
# C:\Users\Dell Latitude 3460\AppData\Local\Temp\ipykernel_16292\762797504.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data6['Inches'].replace('?', np.nan, inplace=True)

# %%
data6.isnull().sum()
# Out:
# Company        0
# TypeName       0
# Inches         1
# Ram            0
# OpSys          0
# Weight         0
# Price          0
# CPU_Type       0
# Memory_Type    0
# GPU            0
# Width          0
# Height         0
# dtype: int64

# %%
data7 = data6.dropna(axis=0)

# %%
data7['Inches'].unique()
# Out:
# array(['13.3', '15.6', '15.4', '14', '12', '17.3', '13.5', '12.5', '13',
#        '18.4', '13.9', '11.6', '25.6', '35.6', '12.3', '27.3', '24',
#        '33.5', '31.6', '17', '15', '14.1', '11.3', '10.1'], dtype=object)

# %%
data7['Inches'] = data7['Inches'].astype('float')
# Out:
# C:\Users\Dell Latitude 3460\AppData\Local\Temp\ipykernel_16292\1009920045.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data7['Inches'] = data7['Inches'].astype('float')

# %%
from sklearn.preprocessing import StandardScaler
sx = StandardScaler()

# %%
cat_data = data7.select_dtypes(include=['object'])
num_data = data7.select_dtypes(include=['int','float'])

# %%
data7['Inches'].unique()
# Out:
# array([13.3, 15.6, 15.4, 14. , 12. , 17.3, 13.5, 12.5, 13. , 18.4, 13.9,
#        11.6, 25.6, 35.6, 12.3, 27.3, 24. , 33.5, 31.6, 17. , 15. , 14.1,
#        11.3, 10.1])

# %%
cat_data.head(10)
# Out:
#   Company   TypeName       OpSys CPU_Type    Memory_Type     GPU
# 0   Apple  Ultrabook       macOS    Intel            SDD   Intel
# 1   Apple  Ultrabook       macOS    Intel  Flash Storage   Intel
# 2      HP   Notebook       No OS    Intel            SDD   Intel
# 3   Apple  Ultrabook       macOS    Intel            SDD     AMD
# 4   Apple  Ultrabook       macOS    Intel            SDD   Intel
# 5    Acer   Notebook  Windows 10      AMD            HDD     AMD
# 6   Apple  Ultrabook    Mac OS X    Intel  Flash Storage   Intel
# 7   Apple  Ultrabook       macOS    Intel  Flash Storage   Intel
# 8    Asus  Ultrabook  Windows 10    Intel            SDD  Nvidia
# 9    Acer  Ultrabook  Windows 10    Intel            SDD   Intel

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for col in cat_data.columns:
    cat_data[col] = le.fit_transform(cat_data[col])

# %%
new_data = pd.concat([cat_data,num_data], axis=1)

# %%
new_data.head(10)
# Out:
#    Company  TypeName  OpSys  CPU_Type  Memory_Type  GPU  Inches  Ram  Weight  \
# 0        1         4      8         1            2    1    13.3    8    1.37
# 1        1         4      8         1            0    1    13.3    8    1.34
# 2        7         3      4         1            2    1    15.6    8    1.86
# 3        1         4      8         1            2    0    15.4   16    1.83
# 4        1         4      8         1            2    1    13.3    8    1.37
# 5        0         3      5         0            1    0    15.6    4    2.10
# 6        1         4      3         1            0    1    15.4   16    2.04
# 7        1         4      8         1            0    1    13.3    8    1.34
# 8        2         4      5         1            2    2    14.0   16    1.30
# 9        0         4      5         1            2    1    14.0    8    1.60
#
#          Price  Width  Height
# 0   71378.6832   2560    1600
# 1   47895.5232   1440     900
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(new_data.corr(), annot=True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
y = new_data[['Price']]
X = new_data.drop(['Price'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_train = lr.predict(X_train)
y_pred_train
# Out:
# array([[16814.44576689],
#        [59405.96271164],
#        [14827.79245805],
#        ...,
#        [90737.58478445],
#        [63523.93627607],
#        [35741.22088041]])

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([[1.38286078e+04],
#        [9.96509665e+04],
#        [9.43075737e+04],
#        [6.28684148e+04],
#        [5.67481452e+04],
#        [6.49545071e+04],
#        [1.03684001e+04],
#        [1.24103551e+05],
#        [6.23588677e+04],
#        [1.10269169e+04],
#        [4.75686659e+04],
#        [6.19049681e+04],
#        [8.78723156e+04],
#        [6.39020219e+04],
#        [6.02120636e+04],
#        [6.36219291e+04],
#        [5.36578899e+04],
#        [9.00798586e+04],
#        [5.35086790e+04],
#        [7.33293133e+04],
#        [7.57464316e+03],
#        [5.87216956e+04],
#        [1.36563103e+04],
#        [5.29721999e+04],
#        [7.06347100e+04],
#        [3.46950169e+04],
#        [5.00078255e+04],
#        [6.76322080e+04],
#        [5.48299676e+04],
#        [6.63256708e+04],
#        [1.89154968e+04],
#        [8.83195102e+04],
#        [9.19262271e+04],
#        [3.20399914e+04],
#        [1.46417888e+05],
#        [5.97885203e+04],
#        [8.60961750e+04],
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_pred, y_test)
mse
# Out:
# 623767549.6457067

# %%
r2 = r2_score(y_pred, y_test)
r2
# Out:
# 0.20126275858662412

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0)

# %%
lasso.fit(X_train, y_train)
# Out:
# c:\Users\Dell Latitude 3460\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\Dell Latitude 3460\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
y_pred_l= lasso.predict(X_test)
y_pred_l
# Out:
# array([1.38286633e+04, 9.96509453e+04, 9.43069861e+04, 6.28684296e+04,
#        5.67481419e+04, 6.49545263e+04, 1.03684097e+04, 1.24103426e+05,
#        6.23588640e+04, 1.10268950e+04, 4.75686721e+04, 6.19049836e+04,
#        8.78723423e+04, 6.39020336e+04, 6.02120851e+04, 6.36219520e+04,
#        5.36579079e+04, 9.00798367e+04, 5.35086787e+04, 7.33293073e+04,
#        7.57465895e+03, 5.87217127e+04, 1.36563162e+04, 5.29722182e+04,
#        7.06347317e+04, 3.46950059e+04, 5.00078660e+04, 6.76322117e+04,
#        5.48299590e+04, 6.63256736e+04, 1.89155356e+04, 8.83195184e+04,
#        9.19262021e+04, 3.20399956e+04, 1.46417851e+05, 5.97885361e+04,
#        8.60961536e+04, 8.88095680e+04, 2.62392192e+04, 8.84269531e+04,
#        5.68086046e+04, 6.19049836e+04, 5.30453787e+04, 2.64772468e+04,
#        1.86570667e+04, 8.80043800e+04, 3.41302839e+04, 1.36496398e+05,
#        5.82628355e+04, 4.17800923e+04, 6.18126775e+04, 4.26609855e+04,
# ...

# %%
y_pred_train_l = lasso.predict(X_train)
y_pred_train_l
# Out:
# array([16814.44750372, 59405.98567179, 14827.7824322 , ...,
#        90737.58274679, 63523.94194511, 35741.21817042])

# %%
r2score_l = r2_score(y_pred_l, y_test)
r2score_l
# Out:
# 0.20126264136641359

# %%
mse_l = mean_squared_error(y_pred_l, y_test)
mse_l
# Out:
# 623767085.7962635

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=0.1)

# %%
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
y_pred_r = ridge.predict(X_test)

# %%
mse_r = mean_squared_error(y_test, y_pred_r)
mse_r
# Out:
# 623199451.1318355

# %%
r2score_r = r2_score(y_pred_r, y_test)
r2score_r
# Out:
# 0.19068800938211306

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree= 5, include_bias=False)
X_train = poly.fit_transform(X_train)
X_test = poly.transform(X_test)

# %%
scaler1 = MinMaxScaler()

# %%
X_train = scaler1.fit_transform(X_train)
X_test = scaler1.transform(X_test)

# %%
regressor1 = LinearRegression()
regressor1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor1.intercept_
# Out:
# array([1.16100751e+12])

# %%
regressor1.coef_
# Out:
# array([[-1.26251013e+12, -1.29715431e+12, -5.37702414e+11, ...,
#          5.90026811e+11,  3.61995210e+11,  1.76336331e+10]])

# %%
y_pred_poly = regressor1.predict(X_test)

# %%
mse = mean_squared_error(y_pred_poly, y_test)
mse
# Out:
# 2.0230085827858457e+22

# %%
r2score_poly = r2_score(y_pred_poly, y_test)
r2score_poly
# Out:
# -0.0016087303677725373

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
decision = DecisionTreeRegressor(criterion='squared_error', max_leaf_nodes=6, random_state=0)

# %%
decision.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=6, random_state=0)

# %%
y_pred_dec_train = decision.predict(X_train)

# %%
y_pred_dec = decision.predict(X_test)

# %%
mse_dec_test = mean_squared_error(y_pred_dec, y_test)
print(mse_dec_test)
r2score_dec_test = r2_score(y_pred_dec, y_test)
print(r2score_dec_test)
# Out:
# 549826402.6219841
# 0.5068348390615152

# %%
mse_dec_train = mean_squared_error(y_pred_dec_train, y_train)
print(mse_dec_train)
r2score_dec_train = r2_score(y_pred_dec_train, y_train)
print(r2score_dec_train)
# Out:
# 377164562.36714303
# 0.6061513689930611

# %%
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor

gb_model = GradientBoostingRegressor(n_estimators=1000,criterion='squared_error',
                                    max_depth=8,min_samples_split=5,
                                    min_samples_leaf=5,max_features=3)

ada_model = AdaBoostRegressor(n_estimators=50,learning_rate=0.1)

xgb_model = XGBRegressor(
    objective='reg:squarederror',
    max_depth=5,
    learning_rate=0.05,
    n_estimators=100
)

gb_model.fit(X_train, y_train)
ada_model.fit(X_train, y_train)
xgb_model.fit(X_train, y_train)
# Out:
# c:\Users\Dell Latitude 3460\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# c:\Users\Dell Latitude 3460\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
# ...

# %%
y_pred_train_gb = gb_model.predict(X_train)
y_pred_train_ada = ada_model.predict(X_train)
y_pred_train_xgb = xgb_model.predict(X_train)

# %%
from sklearn import metrics

# %%
y_test_pred_gb = gb_model.predict(X_test)
y_pred_train_gb = gb_model.predict(X_train)
r2_score_test = round(metrics.r2_score(y_test, y_test_pred_gb),2)
r2_score_train = round(metrics.r2_score(y_train, y_pred_train_gb),2)

print(f'r2_test_gb: {r2_score_test}')
print(f'r2_train_gb: {r2_score_train}')

y_test_pred_ada = ada_model.predict(X_test)
y_pred_train_ada = ada_model.predict(X_train)
r2_score_test = round(metrics.r2_score(y_test, y_test_pred_ada),2)
r2_score_train = round(metrics.r2_score(y_train, y_pred_train_ada),2)

print(f'r2_test_ada: {r2_score_test}')
print(f'r2_train_ada: {r2_score_train}')

y_test_pred_xgb = xgb_model.predict(X_test)
y_pred_train_xgb = xgb_model.predict(X_train)
r2_score_test = round(metrics.r2_score(y_test, y_test_pred_xgb),2)
r2_score_train = round(metrics.r2_score(y_train, y_pred_train_xgb),2)

print(f'r2_test_xgb: {r2_score_test}')
print(f'r2_train_xgb: {r2_score_train}')
# Out:
# r2_test_gb: 0.79
# r2_train_gb: 0.98
# r2_test_ada: 0.72
# r2_train_ada: 0.8
# r2_test_xgb: 0.82
# r2_train_xgb: 0.95
